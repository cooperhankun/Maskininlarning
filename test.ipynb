# %%
import pandas as pd
print("Hej")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [7], in <module>
#       1 import pandas as pd
# ----> 2 import sklearn
#       3 print("Hej")
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import black as bl
help(bl)
# Out:
# Help on package black:
#
# NAME
#     black
#
# PACKAGE CONTENTS
#     __main__
#     brackets
#     cache
#     comments
#     concurrency
#     const
#     debug
#     files
#     handle_ipynb_magics
#     linegen
#     lines
#     mode
#     nodes
#     numerics
#     output
#     parsing
#     report
#     rusty
#     strings
#     trans
#
# CLASSES
#     enum.Enum(builtins.object)
#         WriteBack
#
#     class WriteBack(enum.Enum)
#      |  WriteBack(value, names=None, *, module=None, qualname=None, type=None, start=1)
#      |
#      |  mypyc filler docstring
#      |
#      |  Method resolution order:
#      |      WriteBack
#      |      enum.Enum
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  CHECK = <WriteBack.CHECK: 3>
#      |
#      |  COLOR_DIFF = <WriteBack.COLOR_DIFF: 4>
#      |
#      |  DIFF = <WriteBack.DIFF: 2>
#      |
#      |  NO = <WriteBack.NO: 0>
#      |
#      |  YES = <WriteBack.YES: 1>
# ...
